# %%
from dataset_custom import DatasetCustom

# %%
dataset = DatasetCustom("/home/jailsonpj/Área de Trabalho/mestrado/src/siames_network_tf/exp_1/datasets_custom/")

# %%
df = dataset.get_dataset_custom()

# %%
df
# Out:
#              Source                                              Title  \
# 0           cnn.com                               Stocks slip slightly
# 1     investors.com    Stocks Down At Midday On Weak China Export Data
# 2           cnn.com              Winners and losers of the bull market
# 3       foxnews.com  Does Mt. Gox CEO still control all those stole...
# 4      mashable.com  Bankrupt Exchange Mt. Gox Still Has $600 Milli...
# ...             ...                                                ...
# 9100       theblaze  Bill Cosbys official Instagram account shares ...
# 9101       theblaze  WATCH: Students condemn racist remarks they be...
# 9102       theblaze  Republicans propose constitutional amendment t...
# 9103       theblaze  108 GOP lawmakers sign letter asking Trump to ...
# 9104       theblaze  Despite Trump's threat to close border, Mexico...
#
#                                                 Content label  \
# 0     With little U.S. economic or corporate news on...     0
# 1     Stocks were down across the board at midday Mo...     1
# 2     It's been five years since the stock market hi...     0
# 3     next Image 1 of 3 prev next Image 2 of 3 prev ...     1
# 4     Japan-based Bitcoin exchange Mt.Gox has been d...     0
# ...                                                 ...   ...
# 9100  The official Instagram account of actor Bill C...     1
# 9101  Students at Marymount University in Virginia b...     1
# 9102  President Donald Trump is supporting a propose...     1
# 9103  More than a hundred Republican members of Cong...     1
# 9104  Mexico will not militarize its southern border...     1
#
#                                                    text
# 0     Stocks slip slightly With little U.S. economic...
# 1     Stocks Down At Midday On Weak China Export Dat...
# 2     Winners and losers of the bull market It's bee...
# 3     Does Mt. Gox CEO still control all those stole...
# 4     Bankrupt Exchange Mt. Gox Still Has $600 Milli...
# ...                                                 ...
# 9100  Bill Cosbys official Instagram account shares ...
# 9101  WATCH: Students condemn racist remarks they be...
# 9102  Republicans propose constitutional amendment t...
# 9103  108 GOP lawmakers sign letter asking Trump to ...
# 9104  Despite Trump's threat to close border, Mexico...
#
# [9105 rows x 5 columns]
